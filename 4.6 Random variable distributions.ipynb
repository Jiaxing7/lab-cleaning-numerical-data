# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.Use the numerical variables from our dataset this week.

# %%
data = pd.read_csv('numerical.csv')
data
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# ### 2.Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
import seaborn as sns
import pandas as pd

for col in data.columns:
    sns.histplot(data[col],kde=True)
    plt.title("Distribution of {}".format(col))
    plt.show()

# %%
# just total_claim_amount is almost normal distribution, the others are exponential.

# %% [markdown]
# ### 3.Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
data_log['customer_lifetime_value'] = np.log(data['customer_lifetime_value'])
sns.displot(data_log['customer_lifetime_value'])

# %%
# customer_lifetime_value almost like normal distribution now.

# %%
data_log['monthly_premium_auto'] = np.log(data['monthly_premium_auto'])
sns.displot(data_log['monthly_premium_auto'])

# %%
data_log['months_since_last_claim'] = np.log(data['months_since_last_claim'])
sns.displot(data_log['months_since_last_claim'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data_log['number_of_policies'] = np.log(data['number_of_policies'])
sns.distplot(data_log['number_of_policies'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number_of_policies', ylabel='Density'>
